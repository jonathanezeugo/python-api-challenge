# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import openweathermapy as ow
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import json
import os
import pprint as pprint

# Import API key
from api_keys import g_key
#print(g_key)

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
# Importing Part 1 csv file in DataFrame
raw_data_file_df = pd.read_csv("./output_data/weather_json.csv")   

# Displaying first 5 rows of dataframe
raw_data_file_df.head()
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Port Augusta -32.50  137.77     66.20        77          90       16.11
# 1       Ushuaia -54.80  -68.30     46.40        70          75       20.80
# 2        Albany  42.60  -73.97     15.01        72          75        8.05
# 3   Yellowknife  62.46 -114.35    -40.00        72          20        8.05
# 4        Juneau  58.30 -134.42     30.99        92          90        6.91
#
#   Country        Date
# 0      AU  1608127912
# 1      AR  1608127754
# 2      US  1608127711
# 3      CA  1608127913
# 4      US  1608127913

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
# Store latitude and longitude in locations
locations = raw_data_file_df[['Lat','Lng']]

# Retrieving Humidity data and converting to float
rating = raw_data_file_df["Humidity"].astype(float)

# %%
# Plot Heatmap
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=rating, 
                                 dissipating=False, max_intensity=10,
                                 point_radius=1)


# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# The above heat map shows the coordinates from the imported dataframe

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
# Checking the length or number of rows in the dataframe ahead of cleaning for mapping
len(raw_data_file_df)
# Out:
# 579

# %%
# Dropping all NaN cells from the dataframe
clean_weather_data = raw_data_file_df.dropna(how='any')

# Showing counts across all rows, only 5 rows dropped
clean_weather_data.count()
# Out:
# City          574
# Lat           574
# Lng           574
# Max Temp      574
# Humidity      574
# Cloudiness    574
# Wind Speed    574
# Country       574
# Date          574
# dtype: int64

# %%
# Sorting data for cities with temperatures between 70 and 80 degrees F
ideal_temp_df = clean_weather_data.loc[(clean_weather_data['Max Temp'] > 70) & (clean_weather_data['Max Temp'] < 80)]

# Presenting first 5 rows of dataframe
ideal_temp_df.head()
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 8          Atuona  -9.80 -139.03     78.28        77          11       22.91
# 11  Mar del Plata -38.00  -57.56     72.00        40           0       21.92
# 13         Andapa -14.65   49.65     79.07        69          33        4.12
# 18    East London -33.02   27.91     73.40        69          20        9.17
# 20       Hermanus -34.42   19.23     73.99        62          47        8.01
#
#    Country        Date
# 8       PF  1608127915
# 11      AR  1608127635
# 13      MG  1608127916
# 18      ZA  1608127918
# 20      ZA  1608127918

# %%
# Dropping off rows with Wind Speed less than 10 mph
cut_windsp_df = ideal_temp_df.loc[ideal_temp_df['Wind Speed'] < 10]

# Displaying first 5 rows of dataframe
cut_windsp_df.head()
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 13        Andapa -14.65   49.65     79.07        69          33        4.12
# 18   East London -33.02   27.91     73.40        69          20        9.17
# 20      Hermanus -34.42   19.23     73.99        62          47        8.01
# 34      Kandrian  -6.22  149.55     79.18        85         100        6.24
# 35  Puerto Ayora  -0.74  -90.35     71.01        96          63        4.00
#
#    Country        Date
# 13      MG  1608127916
# 18      ZA  1608127918
# 20      ZA  1608127918
# 34      PG  1608127922
# 35      EC  1608127922

# %%
# Dropping off rows with Cloudiness of 0%
cld_zero_df = cut_windsp_df.loc[cut_windsp_df['Cloudiness'] == 0]

# Displaying first 5 rows of dataframe
cld_zero_df.head()
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 63        Rikitea -23.12 -134.97     76.55        73           0        9.19
# 93     San Rafael -34.62  -68.33     79.32        17           0        6.55
# 122  Kruisfontein -34.00   24.73     78.01        40           0        5.99
# 235   Port Alfred -33.59   26.89     73.99        75           0        9.95
# 251        Nicoya  10.15  -85.45     73.40        94           0        3.36
#
#     Country        Date
# 63       PF  1608127931
# 93       AR  1608127939
# 122      ZA  1608127947
# 235      ZA  1608127977
# 251      CR  1608127981

# %%
# Displaying length or number of rows of dataframe with sorted temperatures of between 70 and 80 F
len(ideal_temp_df)
# Out:
# 122

# %%
# Displaying length or number of rows of dataframe with sorted Wind Speeds of less than 10 mph
len(cut_windsp_df)
# Out:
# 78

# %%
# Displaying length or number of rows of dataframe with sorted zero cloudiness
len(cld_zero_df)
# Out:
# 15

# %%
# Dropping off rows with no numbers or data
hotel_df = cld_zero_df.dropna(how='any')

# Displaying hotel dataframe. 15 cities finalilsts
hotel_df
# Out:
#                City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 63          Rikitea -23.12 -134.97     76.55        73           0
# 93       San Rafael -34.62  -68.33     79.32        17           0
# 122    Kruisfontein -34.00   24.73     78.01        40           0
# 235     Port Alfred -33.59   26.89     73.99        75           0
# 251          Nicoya  10.15  -85.45     73.40        94           0
# 279       Uitenhage -33.76   25.40     78.01        50           0
# 283  Port Elizabeth -33.92   25.57     75.20        50           0
# 337       Bahir Dar  11.59   37.39     77.59        22           0
# 379        Gopālpur  19.27   84.92     73.85        71           0
# 429       Olavarría -36.89  -60.32     73.00        46           0
# 432            Trat  12.50  102.50     76.50        82           0
# 451          Viedma -40.81  -63.00     72.00        31           0
# 468        Santa Fe -31.63  -60.70     75.99        58           0
# 472          Najrān  17.49   44.13     78.80        20           0
# 476         Verāval  20.90   70.37     75.60        41           0
#
#      Wind Speed Country        Date
# 63         9.19      PF  1608127931
# 93         6.55      AR  1608127939
# 122        5.99      ZA  1608127947
# 235        9.95      ZA  1608127977
# 251        3.36      CR  1608127981
# 279        9.17      ZA  1608127967
# 283        9.17      ZA  1608127990
# 337        7.18      ET  1608128005
# 379        4.79      IN  1608128015
# 429        4.00      AR  1608128028
# 432        4.85      TH  1608128029
# 451        7.00      AR  1608127826
# 468        3.00      AR  1608128039
# 472        6.93      SA  1608128040
# 476        8.72      IN  1608128042

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
# Adding "Hotel Name" column to the dataframe
hotel_df["Hotel Name"] = ""

# %%
# Displaying hotel dataframe (first 5 rows)
hotel_df.head()
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 63        Rikitea -23.12 -134.97     76.55        73           0        9.19
# 93     San Rafael -34.62  -68.33     79.32        17           0        6.55
# 122  Kruisfontein -34.00   24.73     78.01        40           0        5.99
# 235   Port Alfred -33.59   26.89     73.99        75           0        9.95
# 251        Nicoya  10.15  -85.45     73.40        94           0        3.36
#
#     Country        Date Hotel Name
# 63       PF  1608127931
# 93       AR  1608127939
# 122      ZA  1608127947
# 235      ZA  1608127977
# 251      CR  1608127981

# %%
# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# Preparing parameters dataframe with keys and values
target_search = "Hotel"
target_radius = 5000 
target_type = "hotel"
params = {"keyword": target_search,"radius": target_radius,"type": target_type,"key": g_key}

# Using FOR loop for populating parameters dictionary
for index, row in hotel_df.iterrows():    
    lat = row["Lat"]
    lng = row['Lng']
    params['location'] = f"{lat},{lng}"
    response = requests.get(base_url, params=params)
    if response.status_code == 200:
        hotels_data = response.json()
        print(json.dumps(hotels_data, indent=4, sort_keys=True))
    
    # Each try to locating parameters of 5000 meters around destination, some hotels go missing, so it shows only successful ones    
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels_data["results"][0]["name"]
    except (KeyError, IndexError):
        print("Missing field/result...skipping.")
hotel_df
# Out:
# {
#     "html_attributions": [],
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -23.1276524,
#                     "lng": -134.9656596
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -23.12637127010728,
#                         "lng": -134.9643498701072
#                     },
#                     "southwest": {
#                         "lat": -23.12907092989272,
#                         "lng": -134.9670495298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Pension Bianca & Benoit",
#             "photos": [
#                 {
#                     "height": 2048,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115150439809622095143\">Fr\u00e9d\u00e9rick B.</a>"
#                     ],
#                     "photo_reference": "ATtYBwK0nyYvXTrc7Civnrn5ypIbmIcutWomvsgnTelueQv9ofOkQ09gs3BHIfssYvtbblr1yDmKtiFMshUK0Z05TpVkAcNaFAm8SbdwwJSAajRTW72VOhCUEHS8ujsKN1hIb_aZ2A95OJExhUFpqCGf-wfThoIjS4m70BFTXc_tbU83RhC3",
#                     "width": 1536
#                 }
#             ],
#             "place_id": "ChIJib4T7laIJ54RcJ1rUHQ9KXk",
#             "plus_code": {
#                 "compound_code": "",
#                 "global_code": "5487V2CM+WP"
#             },
#             "rating": 4.6,
#             "reference": "ChIJib4T7laIJ54RcJ1rUHQ9KXk",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 13,
#             "vicinity": "BP 19 | Archipel des Gambier, Mangareva"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -23.1206197,
#                     "lng": -134.9687529
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -23.11945897010728,
#                         "lng": -134.9673878201073
#                     },
#                     "southwest": {
#                         "lat": -23.12215862989272,
#                         "lng": -134.9700874798928
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Pension Maro'i",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2304,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111098332724302207930\">popa</a>"
#                     ],
#                     "photo_reference": "ATtYBwLDumIOnXYPuxXEjJhftpuoyGXLf9FGw-n0NAjqQzOMcRTffNC0rei9AStVvZbUy0KLWgpBvL06bZDX3hn4oOXLUL4BFQEL4a38Y0baclrdcGWdZd0OVFUlnvYkhf7NUlpfd8unai0jZqMkuMNlFQ1998tsSx0Cj01sYVdz8s1VUEVd",
#                     "width": 4096
#                 }
#             ],
#             "place_id": "ChIJnW6Jh0aIJ54RV2HnC1r0Hjw",
#             "plus_code": {
#                 "compound_code": "",
#                 "global_code": "5487V2HJ+QF"
#             },
#             "rating": 4,
#             "reference": "ChIJnW6Jh0aIJ54RV2HnC1r0Hjw",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 17,
#             "vicinity": "Gambier"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -23.1096583,
#                     "lng": -134.9743477
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -23.073698,
#                         "lng": -134.9292044
#                     },
#                     "southwest": {
#                         "lat": -23.1354104,
#                         "lng": -135.0135122
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/geocode-71.png",
#             "name": "Mangareva",
#             "photos": [
#                 {
#                     "height": 1677,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101672831291437754297\">101672831291437754297</a>"
#                     ],
#                     "photo_reference": "ATtYBwJMFsYO6omWcjeTIzZx4rfhrD-tjNXWShVtvi0-qDhL398WACkVKtRteqwHTrjBxLfRCNgkdpC8EuXuaA6n-fk7zVspvNjo6-Sbeuu08Wdh48uaBbA9_frtKYvORhMfEfqOt0ieStLTTNK-PHdrO9GKswbOhEveG7WWAFT6jYe-TFGS",
#                     "width": 2518
#                 }
#             ],
#             "place_id": "ChIJkRC5RGWIJ54R9kqokhl-dx8",
#             "rating": 4.7,
#             "reference": "ChIJkRC5RGWIJ54R9kqokhl-dx8",
#             "scope": "GOOGLE",
#             "types": [
#                 "natural_feature",
#                 "establishment"
#             ],
#             "user_ratings_total": 19,
#             "vicinity": "Mangareva, French Polynesia"
#         }
#     ],
#     "status": "OK"
# }
# {
#     "html_attributions": [],
#     "next_page_token": "ATtYBwKZTG8fXU7SqZaD_l-jtefbFmsHU759A8L9LjqafB0g0wK85F7tx1cHVNo5RZ0UYeQWglNeC-jgfJ2Lvvm2Rlffcz85QdX42Qcw3FVpJnWuo1gBhCwLznI9VZw5fTyzBsfpHE_VMIOV6YPUqwulCJdO1UhbqbZhtsWrxHMIli3VqL0V-_pn46JFFdozxEe8SrGQyhVOv6o1gPFV93Acnp4XcyIUvu2vvoGLYEEA6xaNYPidYOkTdIZZgktj0g0coJBJsdM9aFLq8buQslzzSujWLFOkUnkwdLEp4xYgq3vCUhXuxVtvWVjTRKurnw2tJRID22iNRsJRJdCbqfqH7TjE_ztrb_XJgjI2yodD1LqWcGVnybRv6L-ueyF27jZhV2Ijafnifx2U3XN7C5mIM8UgzchfSLwAcP3jbfRyIItcklKOz2zo3-vA2yq2uZU",
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -34.6128299,
#                     "lng": -68.339359
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -34.61151292010729,
#                         "lng": -68.33802447010727
#                     },
#                     "southwest": {
#                         "lat": -34.61421257989273,
#                         "lng": -68.34072412989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Tower Inn Hotel & Suites Casino Spa Convention Center",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3648,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103296280994612787248\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwJlPsFpwJhVGEUasgM16eZv_P2NIwNIozCdoFLSl1yeuezqKxHqZirGHuFdkmiONrUi4khKhkhu6oqOkyJTd2H5oZGHvjDy62EAJAn5ZNlMX9cWLHSk9m79qpykbuU_-3X-VUCb6zambCYmmTGfwGt0vzui5pB_i78ZqxGroRJYRU9q",
#                     "width": 5472
#                 }
#             ],
#             "place_id": "ChIJQ2HGAgYIeZYRZC4Db-S7D_s",
#             "plus_code": {
#                 "compound_code": "9MP6+V7 San Rafael, Mendoza Province, Argentina",
#                 "global_code": "47QH9MP6+V7"
#             },
#             "rating": 4.4,
#             "reference": "ChIJQ2HGAgYIeZYRZC4Db-S7D_s",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1549,
#             "vicinity": "Av. Hip\u00f3lito Yrigoyen 774, San Rafael"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -34.6044329,
#                     "lng": -68.3670344
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -34.60274597010727,
#                         "lng": -68.36551257010726
#                     },
#                     "southwest": {
#                         "lat": -34.60544562989272,
#                         "lng": -68.3682122298927
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Suter Petit Hotel",
#             "photos": [
#                 {
#                     "height": 1536,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103549859691200730352\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwKinfdcaWHBbdz0Y8xUitd77wfme7WnS-nc1Y8gz2Xpk8RMesQR35AwYppWs56Z-ktPP-UHpu__cEwP7IH6awxUbmuZ1cbRkqrY0pOpCizsDI1ztUi5be9tW_XSaQ4C-eLRU3B5lOBRl1jiHbPqygCuS8rM7-WgZH4dcsv8gRFrryug",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJ4cUXUA8IeZYR29JCw9yO0hc",
#             "plus_code": {
#                 "compound_code": "9JWM+65 San Rafael, Mendoza Province, Argentina",
#                 "global_code": "47QH9JWM+65"
#             },
#             "rating": 4.3,
#             "reference": "ChIJ4cUXUA8IeZYR29JCw9yO0hc",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 183,
#             "vicinity": "Av. Hip\u00f3lito Yrigoyen 3003, San Rafael"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -34.613873,
#                     "lng": -68.329216
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -34.61257692010728,
#                         "lng": -68.32789317010727
#                     },
#                     "southwest": {
#                         "lat": -34.61527657989272,
#                         "lng": -68.33059282989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hotel San Rafael",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3120,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/117556734205585451285\">Lorena Villagran</a>"
#                     ],
#                     "photo_reference": "ATtYBwLkxo6Od111PLkzt627r5wBWRdu7DpgysJ-CNT9kOPdeJyV5srMYsW-3XetlHz2OMCfSe54EjHRakPEa-UQWgpjpftrmidvWJ1NYF7yaHg06Vcve14RPJ8AE09p3y6iYGiEB_PpSjQP1mJDkwr3kHLyTT3acyP_HAApOx8UvjQbu7Oi",
#                     "width": 4160
#                 }
#             ],
#             "place_id": "ChIJDd5n8PmAGpQRlMFrsp-0lXc",
#             "plus_code": {
#                 "compound_code": "9MPC+F8 San Rafael, Mendoza Province, Argentina",
#                 "global_code": "47QH9MPC+F8"
#             },
#             "rating": 4,
#             "reference": "ChIJDd5n8PmAGpQRlMFrsp-0lXc",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 781,
#             "vicinity": "Cnel. Ricardo Day 30, San Rafael"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -34.615214,
#                     "lng": -68.32578699999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -34.61383907010728,
#                         "lng": -68.32442517010728
#                     },
#                     "southwest": {
#                         "lat": -34.61653872989272,
#                         "lng": -68.32712482989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hotel Francia",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1360,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107739761736741755235\">Hotel Francia</a>"
#                     ],
#                     "photo_reference": "ATtYBwIKwI644E73SDiUDJA5StY5UYCXVcDfXea5ZdQ-1sZDFNZdzQuof2E-IxMZiOQ9gE4biksf-YUxiztnSr4zPdsOmuzzqS8O_uIatps0V0j33RWaiI6YmFFkXNgkybwU4sQ3qFWgyibuRAe41srhgNz7279AkHCz7VUETmBJ0Xx2FGSy",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJAc3GxPsHeZYRlGzVE6Omh2s",
#             "plus_code": {
#                 "compound_code": "9MMF+WM San Rafael, Mendoza Province, Argentina",
#                 "global_code": "47QH9MMF+WM"
#             },
#             "rating": 4.5,
#             "reference": "ChIJAc3GxPsHeZYRlGzVE6Omh2s",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 502,
#             "vicinity": "Francia 248, San Rafael"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -34.607906,
#                     "lng": -68.363553
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -34.60656092010728,
#                         "lng": -68.36222192010727
#                     },
#                     "southwest": {
#                         "lat": -34.60926057989272,
#                         "lng": -68.36492157989271
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "La Caballeriza Posada Boutique",
#             "photos": [
#                 {
#                     "height": 2581,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/113813271302096513092\">La Caballeriza</a>"
#                     ],
#                     "photo_reference": "ATtYBwKAtPjBIuwpxGQF2ECYrbC01vp2JiDa0cTNyk5mjd32Xhf67JmBSgtpbprdIkC4fYxm1Cie4VtLC38Tzm8IkFMjDrYedNqUCZCQyCpWhFU4WN31RVo2pKdOc7_7iIqclyfh-cPpQPulqyrOkGUtkFUIjG6VMFtN4pPWXH2jAC0giMFj",
#                     "width": 3872
#                 }
#             ],
#             "place_id": "ChIJNezoyTgIeZYRNvE8ATlJ4nU",
#             "plus_code": {
#                 "compound_code": "9JRP+RH San Rafael, Mendoza Province, Argentina",
#                 "global_code": "47QH9JRP+RH"
#             },
#             "rating": 4.6,
#             "reference": "ChIJNezoyTgIeZYRNvE8ATlJ4nU",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 129,
#             "vicinity": "Santiago Germano 305, San Rafael"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -34.6154648,
#                     "lng": -68.3314201
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -34.61421212010728,
#                         "lng": -68.33011952010727
#                     },
#                     "southwest": {
#                         "lat": -34.61691177989272,
#                         "lng": -68.33281917989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hotel Kalton",
#             "photos": [
#                 {
#                     "height": 2322,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105871292648559567412\">stella rodas</a>"
#                     ],
#                     "photo_reference": "ATtYBwIHixpXarbgFu_gFAbxIIriK6rZnMRGaDhN8VWu3aBOKIpl5OlwNv3sih9Y2Xf0Qa0T_kc_9a-drbzlB_NQ3I4q8T5G896CkwjnnVKmFBwoG7AlKNj0BV2IcHlXVcVE4g7Tslq2U-32pAgk6K-3bYAF1daZvqlKoXC_y5mJg2maWl67",
#                     "width": 4128
#                 }
#             ],
#             "place_id": "ChIJl9WtHQYIeZYRvm-agzWyQRA",
#             "plus_code": {
#                 "compound_code": "9MM9+RC San Rafael, Mendoza Province, Argentina",
#                 "global_code": "47QH9MM9+RC"
#             },
#             "rating": 4,
#             "reference": "ChIJl9WtHQYIeZYRvm-agzWyQRA",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 610,
#             "vicinity": "Av. Hip\u00f3lito Yrigoyen 120, San Rafael"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -34.614408,
#                     "lng": -68.3411871
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -34.61314047010728,
#                         "lng": -68.33973017010727
#                     },
#                     "southwest": {
#                         "lat": -34.61584012989272,
#                         "lng": -68.34242982989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Apart Hotel Cavis",
#             "photos": [
#                 {
#                     "height": 1280,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110036830016475632488\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwJ2uNxEesvivo-uUslSjN5cITczw1_b0S1KyXRXi89AktXc6eL8WVcm8RtGLnvgaYMueLgcSe1_R2l3uk5NcB2Bx2RpO83lGu4KpvMUBFGkBm2lHz-cer9CTQHT3yb40XCKd2fx45_yQ-lZKAHE5mdMrFRc8KziFNiKqDNeOz0iENeu",
#                     "width": 960
#                 }
#             ],
#             "place_id": "ChIJ4xyB6QUIeZYRCOdDQMj5o_4",
#             "plus_code": {
#                 "compound_code": "9MP5+6G San Rafael, Mendoza Province, Argentina",
#                 "global_code": "47QH9MP5+6G"
#             },
#             "rating": 3.9,
#             "reference": "ChIJ4xyB6QUIeZYRCOdDQMj5o_4",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 375,
#             "vicinity": "Av. Ing. Julio Balloffet 150, ADQ"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -34.619623,
#                     "lng": -68.34698399999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -34.61823122010728,
#                         "lng": -68.34568562010728
#                     },
#                     "southwest": {
#                         "lat": -34.62093087989272,
#                         "lng": -68.34838527989271
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Nuevo Mundo",
#             "photos": [
#                 {
#                     "height": 1080,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100766654048985914856\">luisina arbeloa</a>"
#                     ],
#                     "photo_reference": "ATtYBwJ2qApS7LSorhCZgyyWuXBQXr1upVpllcgPeozkIOOWFQJB5HVqsh6A1_8dKmNKEyubB5mO4jhHhzbNP1UwP0fFdX3iEtKPd3fFPtxGj5UYqmSCvXlwb0Y_QL0KfSUaH93yXwnvdtilFcAlyO37L-ea1MzVfXp5hfKH8VL9_wwFw1WP",
#                     "width": 1920
#                 }
#             ],
#             "place_id": "ChIJdUdZXhsIeZYRriv0hBtAmRo",
#             "plus_code": {
#                 "compound_code": "9MJ3+56 San Rafael, Mendoza Province, Argentina",
#                 "global_code": "47QH9MJ3+56"
#             },
#             "rating": 4.1,
#             "reference": "ChIJdUdZXhsIeZYRriv0hBtAmRo",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 413,
#             "vicinity": "Av. Ing. Julio Balloffet 725, San Rafael"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -34.6130715,
#                     "lng": -68.3538629
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -34.61175407010728,
#                         "lng": -68.35247182010727
#                     },
#                     "southwest": {
#                         "lat": -34.61445372989272,
#                         "lng": -68.35517147989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Tierra Mora",
#             "photos": [
#                 {
#                     "height": 960,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106626970444877636980\">Ariel Y.</a>"
#                     ],
#                     "photo_reference": "ATtYBwLofSvDGgnUSlJzNpn7fJgV-gHicpoezSN7OzCnPh2jnHns9AdpUIvVZ6202ndA8nN9U6B588xBT659EGjo7BqEuOrr7vhoaFymKPX1Hl5RX4_HfM4rbPnBF4R1AhBDaDddWP7FnZ2CKfJUlZNCaH8DAht8RJO9eBF6mYphCGrwM2IQ",
#                     "width": 1440
#                 }
#             ],
#             "place_id": "ChIJsVBi4RYIeZYR4WXANwcASfo",
#             "plus_code": {
#                 "compound_code": "9JPW+QF San Rafael, Mendoza Province, Argentina",
#                 "global_code": "47QH9JPW+QF"
#             },
#             "rating": 4,
#             "reference": "ChIJsVBi4RYIeZYR4WXANwcASfo",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 610,
#             "vicinity": "Florentino Ameghino 350, San Rafael"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -34.5881445,
#                     "lng": -68.3828624
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -34.58685742010727,
#                         "lng": -68.38146947010728
#                     },
#                     "southwest": {
#                         "lat": -34.58955707989272,
#                         "lng": -68.38416912989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Azalea Luxury Lodge",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1836,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106286765367875578315\">Leonardo Daniel Mottino</a>"
#                     ],
#                     "photo_reference": "ATtYBwK9wjdHchUTMXen_PtpA3z4nIOK5OzaPprOksplLtIM4P_VOFVQWOYUu3LRifiVC6FxUNl14UolzHzft26MzXNR3vM_5LC_DcpjzlnOdRDJIjIoQ8eVXUaNQulF6ZuSQV-DqGS1oO7KsyjJZXwT4wzxqj-CQBxKpdiK7cYhU9iiv0su",
#                     "width": 3264
#                 }
#             ],
#             "place_id": "ChIJJwfOdFsIeZYROFYItOnx3dc",
#             "plus_code": {
#                 "compound_code": "CJ68+PV San Rafael, Mendoza Province, Argentina",
#                 "global_code": "47QHCJ68+PV"
#             },
#             "rating": 4.7,
#             "reference": "ChIJJwfOdFsIeZYROFYItOnx3dc",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 231,
#             "vicinity": "Las Virgenes 2882, San Rafael"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -34.6116522,
#                     "lng": -68.3278539
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -34.61032772010729,
#                         "lng": -68.32642257010727
#                     },
#                     "southwest": {
#                         "lat": -34.61302737989273,
#                         "lng": -68.32912222989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "SAN MARTIN HOTEL Y SPA",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2952,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114451391864377106101\">Leonardo Dominguez</a>"
#                     ],
#                     "photo_reference": "ATtYBwLNhqsl-5CMxQzL0H4R-4sF4gSMs8AFxmCAVtAT-mGz2FEuGqChBwVwTSQwAQhreS1DUzfaVHAQ-EhHLtT8v2PxJj9WJ81TBD8KDZM6vJLmogue2AWbkqstY3uTvf6dTIw63YClVFRtJcbTtANJMW_3T9HGQ9jM2KajNJbstTI4q-1v",
#                     "width": 5248
#                 }
#             ],
#             "place_id": "ChIJn-KqoPwHeZYRN0uwF__DKLE",
#             "plus_code": {
#                 "compound_code": "9MQC+8V San Rafael, Mendoza Province, Argentina",
#                 "global_code": "47QH9MQC+8V"
#             },
#             "rating": 4,
#             "reference": "ChIJn-KqoPwHeZYRN0uwF__DKLE",
#             "scope": "GOOGLE",
#             "types": [
#                 "spa",
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1141,
#             "vicinity": "Av. Gral. Jos\u00e9 de San Mart\u00edn 435, San Rafael"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -34.6128206,
#                     "lng": -68.32903999999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -34.61148992010727,
#                         "lng": -68.32770002010727
#                     },
#                     "southwest": {
#                         "lat": -34.61418957989272,
#                         "lng": -68.33039967989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hotel Dali",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2560,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116409388722875467059\">leonel cabrera</a>"
#                     ],
#                     "photo_reference": "ATtYBwIuR8Sd_uwO3EZaJBhBNO2jBZ0BF2nA6QDAXPbm8jYMNbWxY0wG80Bs98QUNlcnfYzdgyewCcgL9l8U8wy8ORkyaBpInBIff5pS5ojBnvGUXQsbGTlD5chOo1M74wRz7oiLvdFtkrtc57sDW-5gRYt-HVUDaxrUts26IVC-ZtQthlpq",
#                     "width": 1920
#                 }
#             ],
#             "place_id": "ChIJZRkfkPwHeZYRWuJ-sN_WXoM",
#             "plus_code": {
#                 "compound_code": "9MPC+V9 San Rafael, Mendoza Province, Argentina",
#                 "global_code": "47QH9MPC+V9"
#             },
#             "rating": 3.6,
#             "reference": "ChIJZRkfkPwHeZYRWuJ-sN_WXoM",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 312,
#             "vicinity": "Gral. Manuel Belgrano 44, San Rafael"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -34.624693,
#                     "lng": -68.287764
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -34.62330222010728,
#                         "lng": -68.28653617010728
#                     },
#                     "southwest": {
#                         "lat": -34.62600187989272,
#                         "lng": -68.28923582989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Apart Hotel Sesma & Caba\u00f1as",
#             "photos": [
#                 {
#                     "height": 3456,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103712830329201739018\">Mario Prada</a>"
#                     ],
#                     "photo_reference": "ATtYBwIa4ooYDaCfLW8OLP1zxPxA9-ydTyvB_voTZ54ekRlyrk0IDSu3vQJDbdvH-QT7cKdBsVjIC6mtbn4CR8nniCvRDrF9a4eLwHDJiUI688HwwcxNFJ_cgMdSsxVzP-BMHoAVMNhy-GUnpKe-hSHykEKgyKGiKSbQ2TaXyfj564hdBeHN",
#                     "width": 4630
#                 }
#             ],
#             "place_id": "ChIJQas4POMHeZYRfHFrF3UG5Oc",
#             "plus_code": {
#                 "compound_code": "9PG6+4V San Rafael, Mendoza Province, Argentina",
#                 "global_code": "47QH9PG6+4V"
#             },
#             "rating": 4.5,
#             "reference": "ChIJQas4POMHeZYRfHFrF3UG5Oc",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 513,
#             "vicinity": "Estanislao Salas 500, San Rafael"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -34.6128975,
#                     "lng": -68.3385158
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -34.61156737010728,
#                         "lng": -68.33710337010727
#                     },
#                     "southwest": {
#                         "lat": -34.61426702989272,
#                         "lng": -68.33980302989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Vecchia Terra apart hotel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 5508,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106662760608114005761\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwKnPD1BpnfWaOnF762MXsf71FKa_rcIFrmhJVWON0w5XSEP_P0G-mGBQG86AlhzA0v8DGro6XHt8f49z6iUJo7-jG97sf0strf7ZykdTD77bkU3kwdQrW6RgwnGsUcYtpgmjwy8O6RSQKkr18P5IGi7DKS38H1LgeFmnScaMSZafDs4",
#                     "width": 8250
#                 }
#             ],
#             "place_id": "ChIJPQnIHwYIeZYRB97D8vXXKQw",
#             "plus_code": {
#                 "compound_code": "9MP6+RH San Rafael, Mendoza Province, Argentina",
#                 "global_code": "47QH9MP6+RH"
#             },
#             "rating": 4.4,
#             "reference": "ChIJPQnIHwYIeZYRB97D8vXXKQw",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 694,
#             "vicinity": "Juan Jos\u00e9 Castelli 23, San Rafael"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -34.603648,
#                     "lng": -68.355717
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -34.60230482010728,
#                         "lng": -68.35435927010727
#                     },
#                     "southwest": {
#                         "lat": -34.60500447989272,
#                         "lng": -68.35705892989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Apart Hotel y Spa Colorina",
#             "photos": [
#                 {
#                     "height": 2340,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110969916031603324314\">marina martinez</a>"
#                     ],
#                     "photo_reference": "ATtYBwJ_h_LNt474u18ECUrb2QhcFfYRLHoQATJqQT6y4Xi-d38lftUXeNsnTE0qaJrcY3aLIBSb8ncVriBLEF3jCJsRBcBvnx_4ZUvCNhwyhDl04S3PxVLUQTgf2NiQIQbnC5fYWxA1Xxtf_j41fF443FMKJ31mtzYsii4hD5dBCf4txhXk",
#                     "width": 4160
#                 }
#             ],
#             "place_id": "ChIJcwFYoWoIeZYRRXlGlUeANvQ",
#             "plus_code": {
#                 "compound_code": "9JWV+GP San Rafael, Mendoza Province, Argentina",
#                 "global_code": "47QH9JWV+GP"
#             },
#             "rating": 4,
#             "reference": "ChIJcwFYoWoIeZYRRXlGlUeANvQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 447,
#             "vicinity": "Canada 315, San Rafael"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -34.619797,
#                     "lng": -68.342911
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -34.61832977010727,
#                         "lng": -68.34149767010729
#                     },
#                     "southwest": {
#                         "lat": -34.62102942989272,
#                         "lng": -68.34419732989274
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#             "name": "Caba\u00f1a de Encanto",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3456,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104122557490148261640\">Mariel Arroyo</a>"
#                     ],
#                     "photo_reference": "ATtYBwI2899vI-pHQm8xnajh6jN3SpUfANBJWrwmL9nizQD_m3LnbPlMJehPsvMyotJ2ao15H_LxiZ1SV-ZrMD4RAcvF8pf6GuV9zARhkFrL-1-QVLrzNgegWF3zfBQtoEzngsliKybe8AjteJRBVEIA_xxSmeiHsSbUjk9srNvxZkpzUel4",
#                     "width": 4608
#                 }
#             ],
#             "place_id": "ChIJC-cidgMIeZYRwpF5jSLfTLQ",
#             "plus_code": {
#                 "compound_code": "9MJ4+3R San Rafael, Mendoza Province, Argentina",
#                 "global_code": "47QH9MJ4+3R"
#             },
#             "rating": 4.6,
#             "reference": "ChIJC-cidgMIeZYRwpF5jSLfTLQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "real_estate_agency",
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 37,
#             "vicinity": "Libertad 799, San Rafael"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -34.5826341,
#                     "lng": -68.34598679999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -34.58126672010729,
#                         "lng": -68.34468887010726
#                     },
#                     "southwest": {
#                         "lat": -34.58396637989273,
#                         "lng": -68.34738852989271
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Posada Boutique La Barrica",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/109609653181712366314\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwLUsodwGh9Bvmt-1cU14QiC3ygsHnVGA5EMzN3fPgcduLzHNP76Y1vuxOxdl7Jena1rtHnI5hamOtdW3E0R0XiISonKIg4n229mwqMurwcxeRGx-Gzz_zotl6wVR2PNVmSgJv0PuIbRSfUegJZthk86zQIlegauJqzrC7L30fk13KoC",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJnZVO0jIJeZYRgyCyJgYhmwU",
#             "plus_code": {
#                 "compound_code": "CM83+WJ San Rafael, Mendoza Province, Argentina",
#                 "global_code": "47QHCM83+WJ"
#             },
#             "rating": 4.7,
#             "reference": "ChIJnZVO0jIJeZYRgyCyJgYhmwU",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 54,
#             "vicinity": "Teresa de, Beata Madre Teresa de Calcuta 2475, San Rafael"
#         },
#         {
#             "business_status": "CLOSED_TEMPORARILY",
#             "geometry": {
#                 "location": {
#                     "lat": -34.6138755,
#                     "lng": -68.3549331
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -34.61257577010728,
#                         "lng": -68.35351987010728
#                     },
#                     "southwest": {
#                         "lat": -34.61527542989273,
#                         "lng": -68.35621952989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "GLR Galeria Hotel Boutique",
#             "permanently_closed": true,
#             "photos": [
#                 {
#                     "height": 960,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106817603934949433842\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwLZKJKJuwIMMhooULaCYSDdRt2zuPDnWmjORP_tdHfyjGGSpHycPJJ0D4R5o0Ah9XrvOlTvWwk77u-r6eEt5qB78TreAbnCuyLW-UyvhMEVUDXZOhgRitnWPnjfPWg5eCP-Updsf65QVmKMtguGACmBVZbWD-cAEDc0_nZmC513e8N_",
#                     "width": 1280
#                 }
#             ],
#             "place_id": "ChIJsQgxQeAJeZYRXh45c5xOh9c",
#             "plus_code": {
#                 "compound_code": "9JPW+C2 San Rafael, Mendoza Province, Argentina",
#                 "global_code": "47QH9JPW+C2"
#             },
#             "rating": 5,
#             "reference": "ChIJsQgxQeAJeZYRXh45c5xOh9c",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 20,
#             "vicinity": "San Rafael Mendoza AR, Florentino Ameghino 478, GXK"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -34.6227402,
#                     "lng": -68.3366942
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -34.62163052010727,
#                         "lng": -68.33475487010729
#                     },
#                     "southwest": {
#                         "lat": -34.62433017989272,
#                         "lng": -68.33745452989274
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Complejo Abraham",
#             "photos": [
#                 {
#                     "height": 3000,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/102095642525554604384\">Erny G.</a>"
#                     ],
#                     "photo_reference": "ATtYBwLBAyapOML7moosyeHT6X0E0T1dSQRBrjdmhPgGQ9JM6zG6EcGbv1iGy3qI_FfshSAfX3OGhAKykq-dofpwoaljbefcsBvWsWokOcmYFXzpBVoKLE1h8HD3PsMp2tvljh32SN9bJG97hPEp-04kQvrBBUs6nXPlk48fB-IrsqG-W1ti",
#                     "width": 5333
#                 }
#             ],
#             "place_id": "ChIJYXqTjP-neZYRZSV_x7NE71A",
#             "plus_code": {
#                 "compound_code": "9MG7+W8 San Rafael, Mendoza Province, Argentina",
#                 "global_code": "47QH9MG7+W8"
#             },
#             "rating": 4.4,
#             "reference": "ChIJYXqTjP-neZYRZSV_x7NE71A",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 284,
#             "vicinity": "299 M5602CJF, Per\u00fa 240, San Rafael"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -34.622608,
#                     "lng": -68.3231081
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -34.62131627010727,
#                         "lng": -68.32178682010728
#                     },
#                     "southwest": {
#                         "lat": -34.62401592989271,
#                         "lng": -68.32448647989271
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Regine Hotel",
#             "photos": [
#                 {
#                     "height": 3072,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107716706683830593980\">Mariana Policicchio</a>"
#                     ],
#                     "photo_reference": "ATtYBwLTP3fdDnYirXk_6jMWk3Mn9GJxCbwa-bJ0s-sl7anBbEwtN6kT8QW81ihV8XscmGlGExz6t7psmjrOnFSLpokh_qmYZXPv9djpsZK-Q7tz87i93B2XZEaovKB-mPHKrhsgDkbStZEVSrYEv5K7WJ5_2Vz-KQ4hb6fR-52GF7gdzEmD",
#                     "width": 4096
#                 }
#             ],
#             "place_id": "ChIJvWnn5wKoeZYRIFASHPbVfDc",
#             "plus_code": {
#                 "compound_code": "9MGG+XQ San Rafael, Mendoza Province, Argentina",
#                 "global_code": "47QH9MGG+XQ"
#             },
#             "rating": 3.9,
#             "reference": "ChIJvWnn5wKoeZYRIFASHPbVfDc",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 540,
#             "vicinity": "Independencia 623, San Rafael"
#         }
#     ],
#     "status": "OK"
# }
# {
#     "html_attributions": [],
#     "results": [],
#     "status": "ZERO_RESULTS"
# }
# Missing field/result...skipping.
# {
#     "html_attributions": [],
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -33.6032154,
#                     "lng": 26.8868014
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -33.60191282010728,
#                         "lng": 26.88804872989272
#                     },
#                     "southwest": {
#                         "lat": -33.60461247989272,
#                         "lng": 26.88534907010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Royal St Andrews Hotel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2000,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107339403132583557105\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwKPbEI9bfPTo0p8KQzGeBPHM7ZS-R5gu71laoRpEiyxD_uRM9VmnzW_fIH37N7SdL1u6ff40XOYNbkCp32a0TP7XKM5K5xiThg1cKjEkPg1YQjzjx-gPZQNhTWSEU9DzHWXCQ9UJ2kor2-9ldoJC5BPCt4F-7sOQfBzEoJNIGwENk-U",
#                     "width": 3171
#                 }
#             ],
#             "place_id": "ChIJSYyzvfnLZR4Rrrjrn5eWNPM",
#             "plus_code": {
#                 "compound_code": "9VWP+PP Port Alfred, South Africa",
#                 "global_code": "4GR89VWP+PP"
#             },
#             "rating": 4.5,
#             "reference": "ChIJSYyzvfnLZR4Rrrjrn5eWNPM",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 405,
#             "vicinity": "19 St Andrews Rd, Port Alfred"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -33.5904314,
#                     "lng": 26.8858279
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -33.58916472010728,
#                         "lng": 26.88700332989272
#                     },
#                     "southwest": {
#                         "lat": -33.59186437989273,
#                         "lng": 26.88430367010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "MyPond Hotel",
#             "photos": [
#                 {
#                     "height": 1340,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100212524143502483753\">Jaco van Rensburg</a>"
#                     ],
#                     "photo_reference": "ATtYBwLS9oU9Id44-YHy5fsUedcA6cgGxz0-oVv4JG4OLujdJ_M9tzZX2stQ_73IC9J6KaFIEiYqvYzlJYpBFNQoG8vMMzzfk1gZhNN5dDmNeqp1COEqt9IBKUNFjGJzbTOWyYO3sz-aRnxQbrA4byDURb1AQhVn1_414bwT0l5XSyEQUtP0",
#                     "width": 2010
#                 }
#             ],
#             "place_id": "ChIJX81PXIvLZR4RRG-td-3aZ_Q",
#             "plus_code": {
#                 "compound_code": "CV5P+R8 Port Alfred, South Africa",
#                 "global_code": "4GR8CV5P+R8"
#             },
#             "rating": 4.2,
#             "reference": "ChIJX81PXIvLZR4RRG-td-3aZ_Q",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 445,
# ...
#             "plus_code": {
#                 "compound_code": "VCW5+6G Somnath, Gujarat, India",
#                 "global_code": "7JGGVCW5+6G"
#             },
#             "rating": 3.6,
#             "reference": "ChIJ0WRvyqIy_TsR1N3wvJTRAxk",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 733,
#             "vicinity": "Railway Station, beside Somnath, near Somnath Bypass Road, Corner, Somnath"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 20.8997025,
#                     "lng": 70.4075096
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 20.90095932989272,
#                         "lng": 70.40876587989271
#                     },
#                     "southwest": {
#                         "lat": 20.89825967010728,
#                         "lng": 70.40606622010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Sarovar Portico Somnath",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1365,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107649913181172442488\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwLNQXzk_XDbRLQ6FkfAOn8m1wuc_DI7bbzOg87nqMNqmkbsML_QzhYkEd1DcB4uryFDPxccyecYCXDS87NyMt87GrdgMngiSRreGNKWRu764uqXobz5DKMbvCseH5EysPryKLPRRDpqbECl5zhBZf8bjLcVVbzp3xnEgiRYSsdY7l-V",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJZ2PS970y_TsRxl-CrC4-4Z8",
#             "plus_code": {
#                 "compound_code": "VCX5+V2 Somnath, Gujarat, India",
#                 "global_code": "7JGGVCX5+V2"
#             },
#             "rating": 4.2,
#             "reference": "ChIJZ2PS970y_TsRxl-CrC4-4Z8",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 456,
#             "vicinity": "Somnath-Junagadh Highway, National Highway No. 8 D. Prabhas Patan, Somnath"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 20.8952989,
#                     "lng": 70.40087179999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 20.89661217989272,
#                         "lng": 70.4022187798927
#                     },
#                     "southwest": {
#                         "lat": 20.89391252010728,
#                         "lng": 70.39951912010727
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "OYO 48307 Hotel Majestic Somnath",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 427,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100607035849227142369\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwLTJiV5Q7DuIcZ8B3pqEde5TpNET0f2iCsDh33_UzhZ-vW-22OgLxSrxjwMyvLF5r4z5It9UoMftjy1lLx15jwpaC2ae4A7AvAavj5Fj-kEmSKYzSd3JZezdiWSHgtxNlELgxwgAPaFOgmE7ZMe1yjJP8GrlXsJGg9e6BoHEvSFhRKA",
#                     "width": 640
#                 }
#             ],
#             "place_id": "ChIJNeMnT3Yz_TsRV1r7v1FADAY",
#             "plus_code": {
#                 "compound_code": "VCW2+48 Somnath, Gujarat, India",
#                 "global_code": "7JGGVCW2+48"
#             },
#             "rating": 4,
#             "reference": "ChIJNeMnT3Yz_TsRV1r7v1FADAY",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 50,
#             "vicinity": "Hotel Majestic, opp. Shiv Police Station, Patan, Somnath"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 20.89998,
#                     "lng": 70.40771
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 20.90123132989272,
#                         "lng": 70.40913382989272
#                     },
#                     "southwest": {
#                         "lat": 20.89853167010728,
#                         "lng": 70.40643417010727
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Sarovar Portico Somnath",
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114937381483615468847\">Riahabh Siddhu</a>"
#                     ],
#                     "photo_reference": "ATtYBwKy4uwekBKEvpTG-DcMmX0qeiZGncxa_rhojO5lg6SZNLOx3P9ISZpEOBfSCwfPc3xwWyYhKlhjSPV26_FVd3d1P7Nu6BmnZphtGEpOpwHXZjuWzlOID9wVOHLTGdT3qD_-ha0MbQoPXCEwssu1tL1tkwitGnJt4zjpN1ubljXmvKSk",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJBTr69L0y_TsRN3EdHvcSaYM",
#             "plus_code": {
#                 "compound_code": "VCX5+X3 Veraval, Gujarat, India",
#                 "global_code": "7JGGVCX5+X3"
#             },
#             "rating": 4,
#             "reference": "ChIJBTr69L0y_TsRN3EdHvcSaYM",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 3,
#             "vicinity": "Railway Station, B/H. Somnath, Veraval"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 20.8954816,
#                     "lng": 70.4120109
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 20.89678437989272,
#                         "lng": 70.41323337989272
#                     },
#                     "southwest": {
#                         "lat": 20.89408472010728,
#                         "lng": 70.41053372010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "OYO 67047 Hotel Om Rudra",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 427,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105809431250419632476\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwKYPI7mMpXJbfPOPsrdhWm4hH234BeyplrNrIpGcQ5OMmHmCXW0bHkSBB7gaMT2FC4XLw7f0L_v32vGlP8QUQXy4MknubrYH06u7yni4NsezBXd53w-QUGbiY8cxYy20i_1vEBPyj2nxk0gq98eIAHTyVsbzTDFFyQXO61LufQdyjZ0",
#                     "width": 640
#                 }
#             ],
#             "place_id": "ChIJk1fgB8sz_TsRcSe-C1b4K6Q",
#             "plus_code": {
#                 "compound_code": "VCW6+5R Somnath, Gujarat, India",
#                 "global_code": "7JGGVCW6+5R"
#             },
#             "rating": 2.3,
#             "reference": "ChIJk1fgB8sz_TsRcSe-C1b4K6Q",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 6,
#             "vicinity": "Hotel Rudra Nr, Somnath Bypass Rd, Corner, Somnath"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 20.934537,
#                     "lng": 70.351827
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 20.93585907989272,
#                         "lng": 70.35305147989271
#                     },
#                     "southwest": {
#                         "lat": 20.93315942010728,
#                         "lng": 70.35035182010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hotel Park",
#             "photos": [
#                 {
#                     "height": 2340,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103558471475734124768\">Amit Shah</a>"
#                     ],
#                     "photo_reference": "ATtYBwK9OrE0QR5eRqtrGygnmVaadknM2WrqErv49KvBNIDKWlV2vlMWIZsmVCi6UxWsa3CKY5mddd_2HW_p08_CQK9o_S0TlIulVZcBszDzujlnXujfHu5JzU5TWtovREJk5i1jBc2d28RFiBvpShe5dzqCsB96qHChi_GL_xYJ_a1xTtak",
#                     "width": 4160
#                 }
#             ],
#             "place_id": "ChIJUcxKisUz_TsRnxhx7XALA-4",
#             "plus_code": {
#                 "compound_code": "W9M2+RP Somnath, Gujarat, India",
#                 "global_code": "7JGGW9M2+RP"
#             },
#             "rating": 3.3,
#             "reference": "ChIJUcxKisUz_TsRnxhx7XALA-4",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 292,
#             "vicinity": "Junagadh Highway Road, Opposite Swamy Narayana Temple, Somnath"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 20.8970229,
#                     "lng": 70.4109489
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 20.89840497989272,
#                         "lng": 70.41229362989273
#                     },
#                     "southwest": {
#                         "lat": 20.89570532010728,
#                         "lng": 70.40959397010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hotel Bansidhar",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 427,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100619179900336699244\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwKWkehhDMHbrVW6DgpYx-4W5h90xjV4YHPGzaEyI6Ig8dhxnastsn7wywHIJs-vvqK7w3MHtBszLK4FHwvV2psMJrjdYQJbXMkvW9uJfRSpT9p-HTkwC_3MXSm6r44gl8sFPjBmeHkFEe5kS4NrwJnpwdP4zAttXW1oeVxOrXQArgbp",
#                     "width": 640
#                 }
#             ],
#             "place_id": "ChIJJyHZJr0y_TsRqh0tjro8Es4",
#             "plus_code": {
#                 "compound_code": "VCW6+R9 Somnath, Gujarat, India",
#                 "global_code": "7JGGVCW6+R9"
#             },
#             "rating": 3.9,
#             "reference": "ChIJJyHZJr0y_TsRqh0tjro8Es4",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 166,
#             "vicinity": "Nr. Hotel, Surbhi, Veraval - Talala Road, Hotel, Somnath"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 20.9060022,
#                     "lng": 70.3843721
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 20.90736077989272,
#                         "lng": 70.38570302989271
#                     },
#                     "southwest": {
#                         "lat": 20.90466112010728,
#                         "lng": 70.38300337010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hotel Harbole",
#             "place_id": "ChIJM-vkZfUy_TsRBH9okPy8_-g",
#             "plus_code": {
#                 "compound_code": "W94M+CP Somnath, Gujarat, India",
#                 "global_code": "7JGGW94M+CP"
#             },
#             "rating": 4.5,
#             "reference": "ChIJM-vkZfUy_TsRBH9okPy8_-g",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2,
#             "vicinity": "Somnath"
#         }
#     ],
#     "status": "OK"
# }
#                City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 63          Rikitea -23.12 -134.97     76.55        73           0
# 93       San Rafael -34.62  -68.33     79.32        17           0
# 122    Kruisfontein -34.00   24.73     78.01        40           0
# 235     Port Alfred -33.59   26.89     73.99        75           0
# 251          Nicoya  10.15  -85.45     73.40        94           0
# 279       Uitenhage -33.76   25.40     78.01        50           0
# 283  Port Elizabeth -33.92   25.57     75.20        50           0
# 337       Bahir Dar  11.59   37.39     77.59        22           0
# 379        Gopālpur  19.27   84.92     73.85        71           0
# 429       Olavarría -36.89  -60.32     73.00        46           0
# 432            Trat  12.50  102.50     76.50        82           0
# 451          Viedma -40.81  -63.00     72.00        31           0
# 468        Santa Fe -31.63  -60.70     75.99        58           0
# 472          Najrān  17.49   44.13     78.80        20           0
# 476         Verāval  20.90   70.37     75.60        41           0
#
#      Wind Speed Country        Date  \
# 63         9.19      PF  1608127931
# 93         6.55      AR  1608127939
# 122        5.99      ZA  1608127947
# 235        9.95      ZA  1608127977
# 251        3.36      CR  1608127981
# 279        9.17      ZA  1608127967
# 283        9.17      ZA  1608127990
# 337        7.18      ET  1608128005
# 379        4.79      IN  1608128015
# 429        4.00      AR  1608128028
# 432        4.85      TH  1608128029
# 451        7.00      AR  1608127826
# 468        3.00      AR  1608128039
# 472        6.93      SA  1608128040
# 476        8.72      IN  1608128042
#
#                                             Hotel Name
# 63                             Pension Bianca & Benoit
# 93   Tower Inn Hotel & Suites Casino Spa Convention...
# 122
# 235                             Royal St Andrews Hotel
# 251                                   Hotel Doña Marta
# 279                         Mountain Retreat at Samara
# 283                                    The Grand Hotel
# 337                                Olive Hotel ኦሊቭ ሆቴል
# 379                MAYFAIR Palm Beach Resort, Gopalpur
# 429                                   Hotel Santa Rosa
# 432
# 451                         Casa Crespo Hotel Boutique
# 468                                   InterTower Hotel
# 472
# 476                                 The Square Somnath

# %%
# Information for the first hotel in the response from json showing Hotel name, city and Country
print(hotels_data["results"][0]["name"])
print(hotels_data['results'][0]['geometry']['location']['lat'])
print(hotels_data['results'][0]['geometry']['location']['lng']) 
print(hotels_data['results'][0]['plus_code']['compound_code'][17:])
# Out:
# The Square Somnath
# 20.8949574
# 70.4122809
# Gujarat, India

# %%
# Displaying all the hotels found at about 5000 meters of the coordinates (first 5 rows)
hotel_df.head()
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 63        Rikitea -23.12 -134.97     76.55        73           0        9.19
# 93     San Rafael -34.62  -68.33     79.32        17           0        6.55
# 122  Kruisfontein -34.00   24.73     78.01        40           0        5.99
# 235   Port Alfred -33.59   26.89     73.99        75           0        9.95
# 251        Nicoya  10.15  -85.45     73.40        94           0        3.36
#
#     Country        Date                                         Hotel Name
# 63       PF  1608127931                            Pension Bianca & Benoit
# 93       AR  1608127939  Tower Inn Hotel & Suites Casino Spa Convention...
# 122      ZA  1608127947
# 235      ZA  1608127977                             Royal St Andrews Hotel
# 251      CR  1608127981                                   Hotel Doña Marta

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Displaying the locations dataframe with Lat and Long data
locations
# Out:
#        Lat     Lng
# 63  -23.12 -134.97
# 93  -34.62  -68.33
# 122 -34.00   24.73
# 235 -33.59   26.89
# 251  10.15  -85.45
# 279 -33.76   25.40
# 283 -33.92   25.57
# 337  11.59   37.39
# 379  19.27   84.92
# 429 -36.89  -60.32
# 432  12.50  102.50
# 451 -40.81  -63.00
# 468 -31.63  -60.70
# 472  17.49   44.13
# 476  20.90   70.37

# %%
# Generating map hotel information
hotel_infor = hotel_df["Hotel Name"].tolist()

# %%
# # Create hotel layer
hotel_layer = gmaps.symbol_layer(
    locations, fill_color='rgba(0, 150, 0, 0.4)',
    stroke_color='rgba(0, 0, 150, 0.4)', scale=6,
    info_box_content=[f"{hotel}" for hotel in hotel_info]
)

# Add the layer to the map
fig = gmaps.figure()
fig.add_layer(heat_layer)
fig.add_layer(hotel_layer)

# Display figure
fig

#
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# The spots in the above map with more colored centers represent the regions with the locations identified in our search

# %%
# Add marker layer on top of heat map
figure_layout = {
    'width': '800px',
    'height': '600px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}
# Assign the marker layer to a variable
markers = gmaps.marker_layer(locations, info_box_content=[f"{hotel}" for hotel in hotel_info])

# Add the layer to the map
fig = gmaps.figure(layout=figure_layout, zoom_level=4, center=(20.94,70.35))

# Layering all maps
fig.add_layer(heat_layer)
fig.add_layer(hotel_layer)
fig.add_layer(markers)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='600px', margin='0 auto 0 auto', padding='1px', wi…

# %% [markdown]
# The above map shows the spot of the first hotel in India. It often changes with every run, but often in India, which would imply they have the best weather and a hotel to help enjoy that weather.
